# %%
import pandas as pd
import json 
import requests
import matplotlib.pyplot as plt
from api_keys import api_key
import datetime

# %%
city_list_original=['sao joao da barra',
 'tumannyy',
 'bredasdorp',
 'illoqqortoormiut',
 'omboue',
 'barentsburg',
 'ushuaia',
 'barentsburg',
 'albany',
 'qaanaaq',
 'ushuaia',
 'qaanaaq',
 'ushuaia',
 'madoc',
 'souillac',
 'port alfred',
 'taolanaro',
 'karakendzha',
 'kruisfontein',
 'illoqqortoormiut',
 'imbituba',
 'xuddur',
 'gulf gate estates',
 'dikson',
 'qaanaaq',
 'longyearbyen',
 'sovetskiy',
 'bredasdorp',
 'ushuaia',
 'narsaq',
 'amsterdam',
 'ushuaia',
 'hermanus',
 'dikson',
 'lichtenburg',
 'ushuaia',
 'ushuaia',
 'barentsburg',
 'longyearbyen',
 'fenton',
 'port alfred',
 'bredasdorp',
 'bredasdorp',
 'punta arenas',
 'arraial do cabo',
 'saint-philippe',
 'ushuaia',
 'mount pleasant',
 'longyearbyen',
 'manaus',
 'bredasdorp',
 'georgetown',
 'ushuaia',
 'barentsburg',
 'grand river south east',
 'qaanaaq',
 'dikson',
 'taolanaro',
 'barentsburg',
 'grand river south east',
 'ushuaia',
 'ornskoldsvik',
 'bredasdorp',
 'qaanaaq',
 'east london',
 'doctor pedro p. pena',
 'jalu',
 'narsaq',
 'mar del plata',
 'codrington',
 'dikson',
 'acarau',
 'georgetown',
 'upernavik',
 'jamestown',
 'bredasdorp',
 'ushuaia',
 'belushya guba',
 'qaanaaq',
 'illoqqortoormiut',
 'belushya guba',
 'ushuaia',
 'illoqqortoormiut',
 'dikson',
 'barentsburg',
 'lasa',
 'illoqqortoormiut',
 'qaanaaq',
 'ushuaia',
 'longyearbyen',
 'tumannyy',
 'bredasdorp',
 'lagoa',
 'illoqqortoormiut',
 'port elizabeth',
 'longyearbyen',
 'hermanus',
 'yabrud',
 'barentsburg',
 'albany',
 'illoqqortoormiut',
 'upernavik',
 'hermanus',
 'jiroft',
 'ushuaia',
 'port alfred',
 'ekibastuz',
 'port elizabeth',
 'castelbuono',
 'vila do maio',
 'east london',
 'cape town',
 'chuy',
 'attawapiskat',
 'barentsburg',
 'clyde river',
 'qaanaaq',
 'bredasdorp',
 'bredasdorp',
 'sao joao de pirabas',
 'longyearbyen',
 'east london',
 'saint anthony',
 'bredasdorp',
 'busselton',
 'antalaha',
 'belushya guba',
 'port alfred',
 'port alfred',
 'longyearbyen',
 'bredasdorp',
 'port alfred',
 'busselton',
 'barentsburg',
 'salym',
 'ushuaia',
 'hermanus',
 'mezen',
 'tsihombe',
 'gilazi',
 'taolanaro',
 'port alfred',
 'hermanus',
 'port elizabeth',
 'dikson',
 'hendrina',
 'riviere-au-renard',
 'qaanaaq',
 'castro',
 'taolanaro',
 'ushuaia',
 'belushya guba',
 'qaanaaq',
 'narsaq',
 'layou',
 'dikson',
 'inongo',
 'dikson',
 'barentsburg',
 'barentsburg',
 'busselton',
 'port alfred',
 'jalu',
 'narsaq',
 'jamestown',
 'port elizabeth',
 'ushuaia',
 'albany',
 'east london',
 'bredasdorp',
 'kovdor',
 'qaanaaq',
 'qaanaaq',
 'hithadhoo',
 'inhambane',
 'ushuaia',
 'albany',
 'ushuaia',
 'krasnovishersk',
 'bredasdorp',
 'port elizabeth',
 'ushuaia',
 'ribeira grande',
 'illoqqortoormiut',
 'illoqqortoormiut',
 'illoqqortoormiut',
 'belushya guba',
 'ushuaia',
 'jacareacanga',
 'albany',
 'dikson',
 'nizwa',
 'illoqqortoormiut',
 'barentsburg',
 'fereydun kenar',
 'ushuaia',
 'bocana de paiwas',
 'ushuaia',
 'belushya guba',
 'port alfred',
 'albany',
 'longyearbyen',
 'port elizabeth',
 'chuy',
 'sorvag',
 'saint-philippe',
 'belushya guba',
 'dikson',
 'voskresenskoye',
 'sur',
 'albany',
 'barentsburg',
 'villazon',
 'afsin',
 'ushuaia',
 'ushuaia',
 'ushuaia',
 'hermanus',
 'ushuaia',
 'barentsburg',
 'hermanus',
 'illoqqortoormiut',
 'malmesbury',
 'bolungarvik',
 'grand river south east',
 'belushya guba',
 'kuusamo',
 'jamestown',
 'longyearbyen',
 'qaanaaq',
 'upernavik',
 'longyearbyen',
 'liverpool',
 'ushuaia',
 'salalah',
 'ratnagiri',
 'ushuaia',
 'margate',
 'saint-louis',
 'marv dasht',
 'bredasdorp',
 'ushuaia',
 'ludvika',
 'busselton',
 'ushuaia',
 'qaanaaq',
 'barentsburg',
 'port elizabeth',
 'qasigiannguit',
 'ushuaia',
 'longyearbyen',
 'qaanaaq',
 'punta arenas',
 'meaford',
 'dikson',
 'hithadhoo',
 'ushuaia',
 'bredasdorp',
 'amderma',
 'hermanus',
 'lutry',
 'jamestown',
 'ushuaia',
 'longyearbyen',
 'port alfred',
 'longyearbyen',
 'mabaruma',
 'ushuaia',
 'hithadhoo',
 'barentsburg',
 'port elizabeth',
 'ushuaia',
 'port elizabeth',
 'barentsburg',
 'qaanaaq',
 'longyearbyen',
 'kidal',
 'jamestown',
 'barentsburg',
 'ribeira grande',
 'tasiilaq',
 'ushuaia',
 'yenotayevka',
 'pisco',
 'solsvik',
 'hermanus',
 'qaanaaq',
 'longyearbyen',
 'ushuaia',
 'bredasdorp',
 'bredasdorp',
 'cayeli',
 'ushuaia',
 'barentsburg',
 'coihaique',
 'sonepur',
 'hermanus',
 'bredasdorp',
 'albany',
 'ushuaia',
 'bambous virieux',
 'souillac',
 'belushya guba',
 'illoqqortoormiut',
 'cabedelo',
 'taolanaro',
 'lerwick',
 'illoqqortoormiut',
 'goderich',
 'inyonga',
 'qaanaaq',
 'tasiilaq',
 'san andres',
 'havoysund',
 'qaanaaq',
 'qaanaaq',
 'saint-philippe',
 'dikson',
 'belushya guba',
 'nassjo',
 'viedma',
 'bredasdorp',
 'barentsburg',
 'grand river south east',
 'port alfred',
 'isiro',
 'ushuaia',
 'bredasdorp',
 'cape town',
 'dikson',
 'ribeira grande',
 'albany',
 'ushuaia',
 'longyearbyen',
 'bredasdorp',
 'ushuaia',
 'narsaq',
 'longyearbyen',
 'ushuaia',
 'bredasdorp',
 'lujan',
 'busselton',
 'ushuaia',
 'sasaram',
 'belushya guba',
 'illoqqortoormiut',
 'berlevag',
 'ushuaia',
 'illoqqortoormiut',
 'dikson',
 'busselton',
 'ushuaia',
 'tete',
 'hermanus',
 'barentsburg',
 'dikson',
 'port alfred',
 'omboue',
 'ponta do sol',
 'bredasdorp',
 'ushuaia',
 'jardim',
 'montepuez',
 'ushuaia',
 'jamestown',
 'albany',
 'lukovetskiy',
 'punta arenas',
 'upernavik',
 'longyearbyen',
 'illoqqortoormiut',
 'chuy',
 'bredasdorp',
 'ushuaia',
 'bredasdorp',
 'bambous virieux',
 'bredasdorp',
 'hermanus',
 'torbay',
 'illoqqortoormiut',
 'illoqqortoormiut',
 'qaanaaq',
 'barentsburg',
 'bredasdorp',
 'torbay',
 'souillac',
 'hithadhoo',
 'dikson',
 'port alfred',
 'umm lajj',
 'busselton',
 'hermanus',
 'paamiut',
 'longyearbyen',
 'grand river south east',
 'bodrum',
 'westport',
 'ushuaia',
 'ushuaia',
 'port elizabeth',
 'paracuru',
 'carnarvon',
 'jamestown',
 'sorland',
 'port elizabeth',
 'lebu',
 'dekoa',
 'lagoa',
 'belushya guba',
 'ushuaia',
 'itarema',
 'albany',
 'ribeira grande',
 'satka',
 'bredasdorp',
 'hermanus',
 'port elizabeth',
 'longyearbyen',
 'pontarlier',
 'east london',
 'illoqqortoormiut',
 'longyearbyen',
 'marcona',
 'illoqqortoormiut',
 'qaanaaq',
 'cidreira',
 'dikson',
 'ushuaia',
 'qaanaaq',
 'bredasdorp',
 'belushya guba',
 'longyearbyen',
 'novosergiyevka',
 'victoria',
 'shahr-e kord',
 'busselton',
 'ushuaia',
 'nikolskoye',
 'ushuaia',
 'panaba',
 'ushuaia',
 'coquimbo',
 'barentsburg',
 'longyearbyen',
 'bredasdorp',
 'longyearbyen',
 'jamestown',
 'busselton',
 'longyearbyen',
 'hermanus',
 'mahebourg',
 'bredasdorp',
 'rocha',
 'upernavik',
 'jamestown',
 'albany',
 'bredasdorp',
 'umm ruwabah',
 'qaanaaq',
 'tasiilaq',
 'hermanus',
 'ushuaia',
 'longyearbyen',
 'dikson',
 'yenotayevka',
 'illoqqortoormiut',
 'port elizabeth',
 'hambantota',
 'longyearbyen',
 'geraldton',
 'qaanaaq',
 'ushuaia',
 'upernavik',
 'belushya guba',
 'port alfred',
 'longyearbyen',
 'illoqqortoormiut',
 'albany',
 'maltahohe',
 'qaanaaq',
 'neuwied',
 'pisco',
 'andrelandia',
 'bredasdorp',
 'ribeira grande',
 'lebu',
 'mossendjo',
 'toliary',
 'hermanus',
 'dejen',
 'barentsburg',
 'qaanaaq',
 'jamestown',
 'behshahr',
 'barentsburg',
 'qaanaaq',
 'san ramon de la nueva oran',
 'ushuaia',
 'dikson',
 'ushuaia',
 'souillac',
 'port alfred',
 'quatre cocos',
 'ushuaia',
 'bredasdorp',
 'necochea',
 'brasileia',
 'bredasdorp',
 'upernavik',
 'malindi',
 'port alfred',
 'ushuaia',
 'longyearbyen',
 'cidreira',
 'punta arenas',
 'hermanus',
 'narsaq',
 'busselton',
 'clyde river',
 'narsaq',
 'sao filipe',
 'longyearbyen',
 'jibuti',
 'qaanaaq',
 'alakurtti',
 'clyde river',
 'illoqqortoormiut',
 'geraldton',
 'belushya guba',
 'mar del plata',
 'port alfred',
 'westport',
 'kajaani',
 'taolanaro',
 'igrim',
 'dingle',
 'dikson',
 'port alfred',
 'kruisfontein',
 'east london',
 'pantelimon',
 'mao',
 'bubaque',
 'illoqqortoormiut',
 'wadi maliz',
 'awjilah',
 'port elizabeth',
 'ushuaia',
 'mango',
 'hermanus',
 'port elizabeth',
 'ushuaia',
 'illoqqortoormiut',
 'albany',
 'ushuaia',
 'grand river south east',
 'qaanaaq',
 'arraial do cabo',
 'roald',
 'georgetown',
 'barentsburg',
 'punta arenas',
 'ushuaia',
 'qaanaaq',
 'ushuaia',
 'kodinar',
 'nanortalik',
 'hermanus',
 'east london',
 'clyde river',
 'purpe',
 'enkhuizen',
 'manta',
 'toliary',
 'amapa',
 'port alfred',
 'ushuaia',
 'hermanus',
 'barentsburg',
 'illoqqortoormiut',
 'port elizabeth',
 'mariakani',
 'constitucion',
 'qaanaaq',
 'ushuaia',
 'ushuaia',
 'geraldton',
 'ushuaia',
 'sao joao da barra',
 'barentsburg',
 'port alfred',
 'ushuaia',
 'hithadhoo',
 'port alfred',
 'springbok',
 'barentsburg',
 'ushuaia',
 'ushuaia',
 'margate',
 'minab',
 'ushuaia',
 'ushuaia',
 'gobabis',
 'albany',
 'longyearbyen',
 'murgab',
 'ust-tsilma',
 'qaanaaq',
 'port blair',
 'qaanaaq',
 'qaanaaq',
 'bredasdorp',
 'ilulissat',
 'port elizabeth',
 'dikson',
 'ugoofaaru',
 'matay',
 'longyearbyen',
 'ushuaia',
 'ushuaia',
 'port elizabeth',
 'barentsburg',
 'ushuaia',
 'qaanaaq',
 'belushya guba',
 'albany',
 'longyearbyen',
 'souillac',
 'takoradi',
 'albany',
 'grand river south east',
 'ushuaia',
 'bredasdorp',
 'ushuaia',
 'rakhya',
 'barentsburg',
 'jumla',
 'dikson',
 'ushuaia',
 'grootfontein',
 'ushuaia',
 'longyearbyen',
 'port elizabeth',
 'iznoski',
 'souillac',
 'bredasdorp',
 'maxixe',
 'arraial do cabo',
 'albany',
 'ushuaia',
 'ushuaia',
 'dikson',
 'ushuaia',
 'qaanaaq',
 'hermanus',
 'grand river south east',
 'birjand',
 'belushya guba',
 'barentsburg',
 'longyearbyen',
 'belushya guba',
 'jizan',
 'longyearbyen',
 'ushuaia',
 'port alfred',
 'dzhusaly',
 'hithadhoo',
 'urumqi',
 'pitimbu',
 'lewisporte',
 'ushuaia',
 'ushuaia',
 'senanga',
 'hendijan',
 'chuy',
 'den helder',
 'belushya guba',
 'longyearbyen',
 'qaanaaq',
 'mar del plata',
 'port alfred',
 'belushya guba',
 'suruc',
 'gulu',
 'hermanus',
 'port alfred',
 'qaanaaq',
 'sao joao da barra',
 'jinka',
 'east london',
 'nusaybin',
 'barentsburg',
 'ushuaia',
 'albanel',
 'sao filipe',
 'ushuaia',
 'punta arenas',
 'hualmay',
 'chiredzi',
 'ushuaia',
 'illoqqortoormiut',
 'cabildo',
 'saint-philippe',
 'longyearbyen',
 'qaanaaq',
 'agadir',
 'barentsburg',
 'belushya guba',
 'miranda',
 'qaanaaq',
 'qaanaaq',
 'illoqqortoormiut',
 'attawapiskat',
 'busselton',
 'ushuaia',
 'ushuaia',
 'awbari',
 'georgetown',
 'qaanaaq',
 'souillac',
 'bredasdorp',
 'bredasdorp',
 'belushya guba',
 'port elizabeth',
 'lichtenburg',
 'qasigiannguit',
 'dikson',
 'ushuaia',
 'ushuaia',
 'upernavik',
 'sao filipe',
 'georgetown',
 'souillac',
 'kongolo',
 'beberibe',
 'geraldton',
 'zubtsov',
 'barentsburg',
 'arraial do cabo',
 'dikson',
 'mashhad',
 'longyearbyen',
 'longyearbyen',
 'barentsburg',
 'bredasdorp',
 'barentsburg',
 'iqaluit',
 'kutum',
 'illoqqortoormiut',
 'dingle',
 'dikson',
 'roald',
 'geraldton',
 'qaanaaq',
 'illoqqortoormiut',
 'mbaiki',
 'ushuaia',
 'port alfred',
 'ushuaia',
 'san cristobal',
 'ushuaia',
 'illoqqortoormiut',
 'illoqqortoormiut',
 'port alfred',
 'barkhan',
 'bredasdorp',
 'port elizabeth',
 'bonavista',
 'upernavik',
 'port alfred',
 'qaanaaq',
 'ushuaia',
 'ushuaia',
 'ilulissat',
 'illoqqortoormiut',
 'ushuaia',
 'albany',
 'dese',
 'upernavik',
 'mar del plata',
 'ushuaia',
 'dikson',
 'ushuaia',
 'iqaluit',
 'hermanus',
 'bandarbeyla',
 'turayf',
 'pangnirtung',
 'bredasdorp',
 'bredasdorp',
 'illoqqortoormiut',
 'cayenne',
 'rafaela',
 'belushya guba',
 'upernavik',
 'ushuaia',
 'binghamton',
 'cozumel',
 'port elizabeth',
 'belushya guba',
 'suez',
 'dikson',
 'qaanaaq',
 'narsaq',
 'barentsburg',
 'ushuaia',
 'sens',
 'beira',
 'upernavik',
 'bredasdorp',
 'ushuaia',
 'busselton',
 'pangnirtung',
 'port elizabeth',
 'huarmey',
 'barentsburg',
 'dikson',
 'ushuaia',
 'port elizabeth',
 'yarmouth',
 'ciudad bolivar',
 'belushya guba',
 'kyshtovka',
 'chapadinha',
 'illoqqortoormiut',
 'yar-sale',
 'hermanus',
 'beni',
 'at-bashi',
 'longyearbyen',
 'belushya guba',
 'barentsburg',
 'camacha',
 'east london',
 'longyearbyen',
 'ushuaia',
 'illoqqortoormiut',
 'longyearbyen',
 'qaanaaq',
 'ushuaia',
 'qaanaaq',
 'upernavik',
 'east london',
 'qaanaaq',
 'ushuaia',
 'ushuaia',
 'porkhov',
 'longyearbyen',
 'longyearbyen',
 'barentsburg',
 'busselton',
 'ushuaia',
 'tasiilaq',
 'barentsburg',
 'port elizabeth',
 'dikson',
 'owerri',
 'cap-aux-meules',
 'illoqqortoormiut',
 'sarakhs',
 'tasiilaq',
 'thompson',
 'reinbek',
 'dikson',
 'saint-georges',
 'manta',
 'narsaq',
 'kruisfontein',
 'dikson',
 'hollola',
 'ushuaia',
 'porto empedocle',
 'hambantota',
 'sechura',
 'belushya guba',
 'ushuaia',
 'bealanana',
 'belushya guba',
 'bambous virieux',
 'ushuaia',
 'ibra',
 'ushuaia',
 'grand river south east',
 'qaanaaq',
 'albany',
 'qaanaaq',
 'ushuaia',
 'kopervik',
 'port elizabeth',
 'bredasdorp',
 'longyearbyen',
 'carballo',
 'touros',
 'longyearbyen',
 'ushuaia',
 'port alfred',
 'ribeira grande',
 'owando',
 'muros',
 'saldanha',
 'namibe',
 'ushuaia',
 'qaanaaq',
 'bredasdorp',
 'qaanaaq',
 'port alfred',
 'illoqqortoormiut',
 'hermanus',
 'taolanaro',
 'dikson',
 'bredasdorp',
 'albany',
 'qaanaaq',
 'ushuaia',
 'ushuaia',
 'ushuaia',
 'albany',
 'barentsburg',
 'carlos antonio lopez',
 'hermanus',
 'bandarbeyla',
 'ushuaia',
 'ushuaia',
 'jamestown',
 'qaanaaq',
 'bredasdorp',
 'dikson',
 'bredasdorp',
 'tasiilaq',
 'pombas',
 'olafsvik',
 'ostrovnoy',
 'bredasdorp',
 'ostrovnoy',
 'castro',
 'longyearbyen',
 'taolanaro',
 'hithadhoo',
 'qaanaaq',
 'longyearbyen',
 'ushuaia',
 'tucurui',
 'ushuaia',
 'nanortalik',
 'bredasdorp',
 'port elizabeth',
 'kumluca',
 'chacabuco',
 'illoqqortoormiut',
 'umm jarr',
 'zhezkazgan',
 'najran',
 'ushuaia',
 'halifax',
 'upernavik',
 'ushuaia',
 'koundara',
 'havre-saint-pierre',
 'ushuaia',
 'mahebourg',
 'inhambane',
 'grand river south east',
 'lagoa',
 'ushuaia',
 'san martin',
 'barentsburg',
 'illoqqortoormiut',
 'abha',
 'albany',
 'port elizabeth',
 'qaanaaq',
 'ushuaia',
 'ushuaia',
 'bengkulu',
 'arraial do cabo',
 'bridlington',
 'longyearbyen',
 'dikson',
 'richards bay',
 'carnarvon',
 'karabulak',
 'ushuaia',
 'port alfred',
 'longyearbyen',
 'tabora',
 'ponta do sol',
 'qaanaaq',
 'bredasdorp',
 'albany',
 'chuy',
 'taoudenni',
 'port alfred',
 'turbat',
 'dikson',
 'ushuaia',
 'ushuaia',
 'aksu',
 'marquette',
 'puerto del rosario',
 'barentsburg']

# %%
city_list_unique=set(city_list_original)
len(city_list_unique)
# Out:
# 291

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build Query url
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
#Set up list to hold response info
lat=[]
long=[]
temp_max=[]
hum=[]
cld=[]
wind=[]
cit=[]
country=[]
date=[]

# %%
nums= 1
print('Beginning Data retrieval')
print('------------------------')
for city in city_list_unique:
   response_json=requests.get(query_url+city).json()
   if str(response_json['cod'])=='404':
       print(f'Missing data city no. {nums} of {len(city_list_unique)}|Skipped {city}')
       nums=nums + 1
   if str(response_json['cod'])!='404':
       try:
           cit.append(city)
           lat.append(response_json['coord']['lat'])
           print(f'Retrieve data city no. {nums} of {len(city_list_unique)}|Added {city}')
           nums=nums+1
       except:
           print('NA')
       try:
           long.append(response_json['coord']['lon'])
       except:
           print('NA')
       try:
           temp_max.append(response_json['main']['temp_max'])
       except:
           print('NA0')
       try:
           hum.append(response_json['main']['humidity'])
       except:
           print('NA1')
       try:
           cld.append(response_json['clouds']['all'])
       except:
           print('NA2')
       try:
           wind.append(response_json['wind']['speed'])
       except:
           print('NA3')
       try:
           country.append(response_json['sys']['country'])
       except:
           print('NA4')
       try:
           date.append(response_json['dt'])
       except:
           print('NA5')
print('----------------------')
print('End of Data retrieval')
# Out:
# Beginning Data retrieval
# ------------------------
# Missing data city no. 1 of 291|Skipped dzhusaly
# Missing data city no. 2 of 291|Skipped tsihombe
# Retrieve data city no. 3 of 291|Added binghamton
# Retrieve data city no. 4 of 291|Added rocha
# Retrieve data city no. 5 of 291|Added karabulak
# Retrieve data city no. 6 of 291|Added cayeli
# Retrieve data city no. 7 of 291|Added halifax
# Missing data city no. 8 of 291|Skipped layou
# Retrieve data city no. 9 of 291|Added pitimbu
# Retrieve data city no. 10 of 291|Added kongolo
# Retrieve data city no. 11 of 291|Added alakurtti
# Retrieve data city no. 12 of 291|Added bonavista
# Retrieve data city no. 13 of 291|Added paracuru
# Retrieve data city no. 14 of 291|Added lerwick
# Retrieve data city no. 15 of 291|Added shahr-e kord
# Retrieve data city no. 16 of 291|Added mabaruma
# Retrieve data city no. 17 of 291|Added nassjo
# Retrieve data city no. 18 of 291|Added minab
# Retrieve data city no. 19 of 291|Added xuddur
# ...

# %%
print(f'city  {len(cit)} latitude {len(lat)} long {len(long)} temp {len(temp_max)} humidity {len(hum)}')
# Out:
# city  256 latitude 256 long 256 temp 256 humidity 256

# %%
weather_data=pd.DataFrame()
weather_dict={
   'City': cit,
   'Latitude': lat,
   'Longitude': long,
   'Max Temperature': temp_max,
   'Humidity': hum,
   'Cloudiness': cld,
   'Wind Speed': wind,
   'City Country': country,
   'City Date': date
}
weather_data=pd.DataFrame(weather_dict)
weather_data
# Out:
#                   City  Latitude  Longitude  Max Temperature  Humidity  \
# 0           binghamton     42.10     -75.91            66.00        93
# 1                rocha    -34.48     -54.34            42.74        82
# 2            karabulak     44.91      78.49            61.64        29
# 3               cayeli     41.09      40.73            66.32        69
# 4              halifax     44.65     -63.58            68.00        93
# 5              pitimbu     -7.47     -34.81            75.20        94
# 6              kongolo     -5.39      27.00            73.16        79
# 7            alakurtti     66.96      30.34            55.99        79
# 8            bonavista     48.65     -53.11            57.00        84
# 9             paracuru     -3.41     -39.03            80.60        74
# 10             lerwick     60.15      -1.15            48.20        93
# 11        shahr-e kord     32.33      50.85            50.00        39
# ...

# %%
weather_data.to_csv(r"C:\Users\Owner\Documents\School\Homework\Pandas_API_Week_6\weather_data.csv",index=False)

# %%
today_date=datetime.date.today()
plt.scatter(weather_data['Latitude'],weather_data['Max Temperature'],c='blue',marker="o",edgecolor="black")
plt.title(f'Latitude vs Max Temperature {today_date}')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.grid()
plt.savefig(r"C:\Users\Owner\Documents\School\Homework\Pandas_API_Week_6\latitudevs_maxtemp.png")

# %%
today_date=datetime.date.today()
plt.scatter(weather_data['Latitude'],weather_data['Humidity'],c='red',marker="o",edgecolor="black")
plt.title(f'Latitude vs Humidity {today_date}')
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.savefig(r"C:\Users\Owner\Documents\School\Homework\Pandas_API_Week_6\latitudevs_humidity.png")

# %%
today_date=datetime.date.today()
plt.scatter(weather_data['Latitude'],weather_data['Cloudiness'],c='green',marker="o",edgecolor="black")
plt.title(f'Latitude vs Cloudiness {today_date}')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.savefig(r"C:\Users\Owner\Documents\School\Homework\Pandas_API_Week_6\latitudevs_cloudiness.png")

# %%
today_date=datetime.date.today()
plt.scatter(weather_data['Latitude'],weather_data['Wind Speed'],c='yellow',marker="o",edgecolor="black")
plt.title(f'Latitude vs Wind Speed {today_date}')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.savefig(r"C:\Users\Owner\Documents\School\Homework\Pandas_API_Week_6\latitudevs_windspeed.png")
